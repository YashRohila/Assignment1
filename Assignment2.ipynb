# %% [markdown]
# 1. What are data structures, and why are they important
# - Data structures in Python are tools for organising and managing data effeciently. Python has inbuilt data structures such as:
# -List, Dictonaries, Tuples and sets
# - They are important because of smooth data handling, improved algorithms , problem solving and algorithms
#
# 2.Explain the difference between mutable and immutable data types with examples
# - Mutable data types are the ones which can be changed after declaration. It changes the orginal object without creating new one
# - Example of mutable:
# numbers=[1,2,3] numbers.append(4) print(numbers) Output: [1,2,3,4]
# - Immutable are the data types which can not be changed after creation.
# - Example of imutable: coordinates(1,2) coordinates[0]=3 #This will show an error because tuples are immutable
#
# 3.What are the main differences between lists and tuples in Python
# - The main difference between list and tuple is that list are mutable and tuples are immutable.
# - There is syntax difference too for list we use [] brackets and for tuples we use () brackets
# - The performance of list are slow because they can be changed and tuples are faster than list because of its immutable behaviour
# - List support methods like append(), remove whereas tuple support count(),index()
# - List are unhashable and tuples are hashable
#
# 4.  Describe how dictionaries store data
#
# - Dictonaries save data in form of key and value pair
# - Example: my_dict={"name":"yash","age":25}
#
# 5. Why might you use a set instead of a list in Python?
# - For unique elements
# - For fast memebership testing
# - For performing set operations like union, intersection and difference.
#
# 6. What is a string in Python, and how is it different from a list
# - String are immutable and List is mutable
# - The data type of string is sequence of characters and for list it is sequence of elements such which can be of any type.
# - Strings are enclosed in '' or "" but List are enclosed in []
# - Strings include method like .upper(),.lower() and .replace() whereas List include methods like .append(),.pop(),.sort()
#
#
# 7.  How do tuples ensure data integrity in Python
# - Tuples ensures data integrirty by being immutable, hashable which resist to accidental or intentional modification
#
# 8.  What is a hash table, and how does it relate to dictionaries in Python?
# - Hashtable is a data structure which stores the data in term of key value pairs. It uses hash function to compute and index for a given key which shows that the key value pair is store at the index.
# - Hash table is directly connected to dictionaries because dictionaries are saved in the form of key-value pair
#
# 9. Can lists contain different data types in Python?
# - Yes list can contain different data types in Python. It can store mix of int, float ,string, object,list and many more.
# - Example: li= [42,"hello", True, [1,2,3], 1.25]
#
# 10. Explain why strings are immutable in Python
# - Strings are immutable in Python to ensure: -
# - Effeciency in memory usage
# - Safety by preventing unintended modifications
# - Reliability in data structures
# - Optimization
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
# - Dictionary doesnt have duplicates which ensures data integrity
# - Dictionaries have unique key value association
# - For faster lookups
# - When we dont need data to be in order but needed to accessed by unique key identifier
#
# 12. Describe a scenario where using a tuple would be preferable over a list
# - We will use tuple over list where we need data to be consistent, immutable and data intended to remain unchanged tuples would be prefer over list because tuples give data integrity, performance benefits and clarity.
#
# 13.  How do sets handle duplicate values in Python?
# - In python sets automatically handle duplicate values by eliminating them to ensure every element in a set is unique.
#
# 14.  How does the “in” keyword work differently for lists and dictionaries?
# - In list "in" keyword checks the presence of value in list whereas in dictionaries "in" keyword search for key not values
#
# 15.  Can you modify the elements of a tuple? Explain why or why not?
# - We can not modify the elements of tuple because tuples are immutable.
#
# 16. What is a nested dictionary, and give an example of its use case/
# - Nested dictionary are te dictionary where values of the key are dictonary itself which is good for storing heirichal data.
# - students ={ "student1": "name":"yash", "age":25, "grades": {"maths":85,"science":95}}
#
# 17.Describe the time complexity of accessing elements in a dictionary
# - The time complexity of accessing elements in dictionary depends on following factorrs:
# - Average case O(1) , Worst case O(n)
#
# 18.  In what situations are lists preferred over dictionaries
# - List are preferred over dictionaries when we need :
# - Order or sequential data
# - Need index based access
# - To do iteration over a simple sequence values
# - where we want to work with simple data rather than key value data
# - when memory effeciency is a concern
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval
# - Dictionaries are implemented using hashtable. hashtable uses has function to map key to specific location in memory
# - Theres is no relatioship between key order and physical relation in menorty
#
# 20. Explain the difference between a list and a dictionary in terms of data retrieval
# - List is an ordered collection of elements whereas dictionary is unorderd collection of key value pairs.
# - List allows duplicate values but dictionary requires unique keys
# - In list we retrieve data by indices but in dictionary we retreive by keys

# %%
#1. Write a code to create a string with your name and print it
name="yash"
print(name)

#2 Write a code to find the length of the string "Hello World"
y=len("helloworld")
print(y)

#3  Write a code to slice the first 3 characters from the string "Python Programming"
y="Python Programming"
print(y[:3])

#4  Write a code to convert the string "hello" to uppercase
y="hello"
print(y.upper())

#5 Write a code to replace the word "apple" with "orange" in the string "I like apple"
y="I like apple"
print(y.replace("apple","orange"))

#6 Write a code to create a list with numbers 1 to 5 and print it
li=[1,2,3,4,5]
print(li)

#7 Write a code to append the number 10 to the list [1, 2, 3, 4]
li=[1,2,3,4]
li.append(10)
print(li)

#8 Write a code to remove the number 3 from the list [1, 2, 3, 4, 5]
li=[1,2,3,4,5]
li.remove(3)
print(li)

#9 Write a code to access the second element in the list ['a', 'b', 'c', 'd']
li=['a','b','c','d']
print(li[1])

#10 Write a code to reverse the list [10, 20, 30, 40, 50]
li=[10,20,30,40,50]
li.reverse()
print(li)
# Out:
# yash
# 10
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (10, 20, 30)

# %%
#11 Write a code to create a tuple with the elements 10, 20, 30 and print it
tu=(10,20,30)
print(tu)

#12  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')
tup=('apple','banana','cherry')
print(tup[0])

#13  Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
z=(1,2,3,2,4,2)
print(z.count(2))

#14  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
m=('dog', 'cat', 'rabbit')
print(m.index('cat'))

#15 Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
k=('apple', 'orange', 'banana')
if 'banana' in k:
  print("true")
else:
  print("false")

#16 Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it
m={1,2,3,4,5}
print(m)

#17  Write a code to add the element 6 to the set {1, 2, 3, 4}
a={1, 2, 3, 4}
a.add(6)
print(a)

#18  Write a code to create a tuple with the elements 10, 20, 30 and print it
l=(10,20,30)
print(l)

#19  Write a code to access the first element of the tuple ('apple', 'banana', 'cherry')
m=('apple', 'banana', 'cherry')
print(m[0])

#20 Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2)
o=(1, 2, 3, 2, 4, 2)
x=o.count(2)
print(x)
# Out:
# (10, 20, 30)
# apple
# 3
# 1
# true
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4, 6}
# (10, 20, 30)
# apple
# 3

# %%
#21  Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')
p=('dog', 'cat', 'rabbit')
print(p.index('cat'))


#22 Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana')
k=('apple', 'orange', 'banana')
if 'banana' in k:
  print("true")
else:
  print("false")

#23  Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it
z={1,2,3,4,5}
print(z)

#24 Write a code to add the element 6 to the set {1, 2, 3, 4}
a={1, 2, 3, 4}
a.add(6)
print(a)
# Out:
# 1
# true
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4, 6}
