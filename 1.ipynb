# %% [markdown]
#   1. What is Python, and why is it popular?
#    - Python is a programming language. Python is famous because of its versality, ease of use and have lot of different libraries which can be used for data manipulation ,visualization, statical analysis, machine learning. Also Python has active and growing community which works on continous development on availability of resources.
#
#   2. What is an interpreter in Python?
#    - Intepreter is a program that reads and execute the code of python line by line .It actually converts the high level code to the machine code which can be understand by computer easily
#
#   3. What are pre-defined keywords in Python
#    - Predefined keywords are reserved keyword that has special meaning which can not be used as identifiers such variable and functions names.There are total 35 pre defined keywords in python.
#    The prefedefined keyword are as follows:-
#    False, None, True, and, as, assert, async, await, break, class, continue, def, del, elif, else, except, finally, for, from, global, if, import, in, is, lambda, nonlocal, not, or, pass, raise, return, try, while, with, yield
#
#   4. Can keywords be used as variable names?
#    - No keywords can not be used as variavle names because if do that it will show an error.
#
#    5. What is mutability in Python
#    - Mutability means that we can change the value or content of an object in Python after creation
#    - Example: list,dictionaries,set
#    - Code: list1=[1,2,3,4]
# list1[0]=5
# print(list1)
#
#    6. Why are lists mutable, but tuples are immutable?
#    - Lists are mutable because they are designed to be dynamic collections.They They allow for add, removal and modifying there are made for such situation where data can change during program execution.
#    - Code:-> list1=[1,2,3,4]
#      list1[0]=5
#      print(list1)
#    - On the other hand tupples are fixed data collections.Once tupples are made it can not changed which gives us several benefits such as performance, hashibiliy and security.
# What is the difference between “==” and “is” operators in Python
#    7.
#    - Equality(==) :-> It checks the values of two objects are equals or not.If there are two different objects and their values are same they are considered to be true.
#    - x=[1,2,3,4]
# y=x;
# z=[1,2,3,4]
# if(x[0]==z[0]):
#     print("true")
# else:
#     print("false")
#    - Identity(is) :-> It refers to the value of variable refer to the same object or not.
#    - x=[1,2,3,4]
# y=x;
# z=[1,2,3,4]
# if (x is y):
#     print("true")
# if(x is z):
#     print("true")
# else:
#     print("false")
#
#    8. What are logical operators in Python
#    - Logical operator are used to perform logical operations on boolean values. They help in combining multiple conditions and expression to give a boolean resultant value.
#    - Logical operators are: and, or and not.
#
#    9. What is type casting in Python
#    - Type casting in python converts one data type to another data type using in-built functions.
#    - x="123"
# y=int(x)
# print(type(y))
#
#    10. What is the difference between implicit and explicit type casting?
#    - Implicit :-> In this one type of conversion is done into another automatically by the Interpreter. There is low risk of error.
#    - a=2 b=3.5 c=a+b print(c)  //Converted to float
#    - Explicit :-> This type of conversion is done manually by the programmer by using type conversion. There can be data loss when not done correctly.
#    - x="123"
# y=int(x)
# print(type(y))
#
#    11. What is the purpose of conditional statements in Python
#    - The main purpose of conditional statements are to make decisions and execut the relevant code which depends on condition wheather its true or false
#    -a=85
# if(a>=90):
#     print("grade a")
# elif(a>=80):
#     print("grade b")
# else:
#     print("grade c")
#
#     12. How does the elif statement work?
#     - It is used to check multiple conditions in a sequence which will be better understand by a code
#     -a=75
# if(a>=90):
#     print("grade a")
# elif(a>=80):
#     print("grade b")
# elif(a>=70):
#     print("grade c")
# else:
#     print("fail")
#
#     13. What is the difference between for and while loops
#     - The major difference betweeen both of them is of syntax.
#     - for loop runs where number of iterations are finite and known and while loop we do not know about the number of iterations.
#     - for loop iterate over string, list and ranges whereas in while until the task is done it  keeps on running
#     - for loop:- for i in range(5):
#     print(i)
#     - while loop:- i=0 while(i<5):
#     print(i) i=i+1
#
#     14. Describe a scenario where a while loop is more suitable than a for loop.
#     - while loop is more suitable than for loop where we do not know about the number of iterations. We can take example of use login where we are not known that how many time user want to login.

# %%
1. Write a Python program to print "Hello, World!
 print("hello world")

2. Write a Python program that displays your name and age
name="yash"
age="24"
print(name)
print(age)

3. Write code to print all the pre-defined keywords in Python using the keyword library
import keyword
print(keyword.kwlist)

4. Write a program that checks if a given word is a Python keyword
import keyword
word=input("enter the keyword")
if(keyword.iskeyword(word)):
    print("python keyword")
else:
    print("no keyword")

5.Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
for each
list1=[1,2,3,4]
print("orginial list:",list1)

list1[0]=5
print("new list:",list1)

tuple1=(1,2,3,4)
print("orginial tuple:",tuple1)

tuple1[0]=5
# for tuple 1 showed an error which said 'tuple' object does not support item assignment

6. Write a function to demonstrate the behavior of mutable and immutable arguments
For immutable string before and after modification
S="YASH"
s_new=S.replace("Y","Z")
s_new



for mutable list before and after modification
S="YASH"
s_new=S.replace("Y","Z")
s_new





7. Write a function to demonstrate the behavior of mutable and immutable arguments
For immutable string before and after modification
S="YASH"
s_new=S.replace("Y","Z")
s_new



for mutable list before and after modification
S="YASH"
s_new=S.replace("Y","Z")
s_ne





8.Write a program to demonstrate the use of logical operators
x=5
y=10

if(x>0 and y> 0):
    print("both are greater than 0")

if(x>0 or y<5):
    print("either x is greater than 0 or y is lesser than 5")

if not(x <0):
    print("x is not less than 0")

9.Write a Python program to convert user input from string to integer, float, and boolean types
x="1"
y=int(x)
z=float(x)
l=bool(x)
print(type(x))
print(type(y))
print(type(z))
print(type(l))

10. Write code to demonstrate type casting with list elements
my_list = ["1", "2", "3.5", "True", "45"]

intlist=[int(float(item)) if item.replace('.','',1).isdigit() else 0 for item in my_list]
print(intlist)

floatlist=[float(item) if item.replace('.','',1).isdigit() else 0.0 for item in my_list]
print(floatlist)

boolist=[bool(item) for item in my_list]
print(boolist)

11.0 Write a program that checks if a number is positive, negative, or zero
z=input("Enter the number")
a=int(z)
if(a<0):
    print("less than 0")
elif(a>0):
    print("greater than 0")
else:
    print("equals to 0")

12. Write a for loop to print numbers from 1 to 10
for i in range(1,11):
    print(i)

13. Write a Python program to find the sum of all even numbers between 1 and 50
sumeven=0
for i in range(1,51):
    if(i%2==0):
        sumeven=sumeven+i
    else:
        continue

print(sumeven)

14. Write a program to reverse a string using a while loop
n="yash"
rs=""
index=len(n)-1
while(index>=0):
    rs+=n[index]
    index=index-1
print(rs)

15. Write a Python program to calculate the factorial of a number provided by the user using a while loop.
n=5
factorial=1
while(n>=1):
    factorial=factorial*n
    n=n-1
print(factorial)
